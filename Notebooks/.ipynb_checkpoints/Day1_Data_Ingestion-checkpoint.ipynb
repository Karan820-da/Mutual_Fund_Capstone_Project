# %% [markdown]
# # Day 1 - Data Ingestion & Profiling
#
# ## Objectives
# - Load all mutual fund datasets
# - Perform dataset profiling
# - Check data quality issues
# - Validate AMFI codes
# - Integrate live NAV API
# - Prepare project structure
#
# ## Deliverables
# - Raw datasets loaded
# - Data quality report
# - Live NAV fetch script
# - GitHub repository setup

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
fund_master = pd.read_csv("../Data/Raw/01_fund_master.csv")
nav_history = pd.read_csv("../Data/Raw/02_nav_history.csv")

print("Fund Master Shape:", fund_master.shape)
print("NAV History Shape:", nav_history.shape)
# Out:
# Fund Master Shape: (40, 15)
# NAV History Shape: (46000, 3)

# %%
datasets = {
    "Fund Master": fund_master,
    "NAV History": nav_history
}

for name, df in datasets.items():
    print(f"\n{name}")
    print("-"*30)
    print("Shape:", df.shape)
    print("Missing Values:", df.isnull().sum().sum())
    print("Duplicates:", df.duplicated().sum())
# Out:
# Fund Master
# ------------------------------
# Shape: (40, 15)
# Missing Values: 0
# Duplicates: 0
#
# NAV History
# ------------------------------
# Shape: (46000, 3)
# Missing Values: 0
# Duplicates: 0

# %% [markdown]
# ## Data Quality Findings
#
# - Dataset structure validated.
# - Missing values identified.
# - Duplicate records checked.
# - Column data types reviewed.

# %%
import requests

url = "https://api.mfapi.in/mf/125497"

response = requests.get(url)

print("Status Code:", response.status_code)
# Out:
# Status Code: 200

# %% [markdown]
# ## Live NAV API Integration
#
# The MFAPI endpoint was tested for live NAV retrieval.
#
# Challenges:
# - Intermittent 502 Bad Gateway errors.
# - API availability inconsistent.
#
# Successful responses were converted into Pandas DataFrames for further analysis.
