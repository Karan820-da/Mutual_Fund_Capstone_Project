# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

plt.style.use("ggplot")

# %%
nav = pd.read_csv(
    "../Data/Processed/clean_nav_history.csv"
)
transactions = pd.read_csv(
    "../Data/Processed/clean_investor_transactions.csv"
)
holdings = pd.read_csv(
    "../Data/Processed/clean_portfolio_holdings.csv"
)
scorecard = pd.read_csv(
    "../Outputs/fund_scorecard.csv"
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 10
#       4 transactions = pd.read_csv(
#       5     "../Data/Processed/clean_investor_transactions.csv"
#       6 )
#       7 holdings = pd.read_csv(
#       8     "../Data/Processed/clean_portfolio_holdings.csv"
#       9 )
# ---> 10 scorecard = pd.read_csv(
#      11     "../Outputs/fund_scorecard.csv"
#      12 )
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\karan\OneDrive\Desktop\Mutual_Fund_Capstone_Project\Notebooks

# %%
os.listdir("..")
# Out:
# ['.git',
#  'bluestock_mf.db',
#  'Dashboard',
#  'Data',
#  'data_dictionary.md',
#  'data_ingestion.py',
#  'live_nav_fetch.py',
#  'Notebooks',
#  'README.md',
#  'reports',
#  'requirements.txt',
#  'sql']

# %%
os.listdir("../Outputs")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 os.listdir("../Outputs")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../Outputs'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Day1_Data_Ingestion.ipynb',
#  'Day2_Data_Cleaning.ipynb',
#  'Day3_EDA_Analysis.ipynb',
#  'Day4_Performance_Analytics.ipynb',
#  'day6 _Advanced_Analytics.ipynb',
#  'Mutual_Fund_Capstone_Project.ipynb']

# %%
import os

for root, dirs, files in os.walk(".."):
    for file in files:
        if "scorecard" in file.lower():
            print(os.path.join(root, file))
# Out:
# ..\Data\Processed\fund_scorecard.csv
# ..\reports\top10_fund_scorecard.png

# %%
v = pd.read_csv(
    "../Data/Processed/clean_nav_history.csv"
)
transactions = pd.read_csv(
    "../Data/Processed/clean_investor_transactions.csv"
)
holdings = pd.read_csv(
    "../Data/Processed/clean_portfolio_holdings.csv"
)
scorecard = pd.read_csv(
    "../Data/Processed/fund_scorecard.csv"
)

# %%
nav.head()
# Out:
#    amfi_code        date       nav
# 0     100016  2022-01-03  520.4608
# 1     100016  2022-01-04  515.0971
# 2     100016  2022-01-05  521.7239
# 3     100016  2022-01-06  515.7880
# 4     100016  2022-01-07  515.1639

# %%
transactions.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
holdings.head()
# Out:
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date
# 0           737.09            6011.08     2025-12-31
# 1            88.97            1074.65     2025-12-31
# 2           208.45            5964.59     2025-12-31
# 3           161.32            3748.82     2025-12-31
# 4           725.90            1321.45     2025-12-31

# %%
scorecard.head()
# Out:
#    amfi_code                                        scheme_name  \
# 0     119598         SBI Small Cap Fund - Regular Plan - Growth
# 1     120505           ICICI Pru Midcap Fund - Regular - Growth
# 2     149324              DSP Small Cap Fund - Regular - Growth
# 3     100033  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 4     120843             Kotak Flexicap Fund - Regular - Growth
#
#    return_3yr_pct  expense_ratio_pct  sharpe_ratio     alpha      beta  \
# 0           23.39               1.43      0.945308  0.303370 -0.023196
# 1           18.08               1.36      1.180101  0.292636  0.000549
# 2           20.08               1.52      0.949796  0.300579  0.011455
# 3           16.58               1.38      1.093699  0.271954  0.005104
# 4           15.65               1.45      1.306744  0.273305 -0.022830
#
#    max_drawdown  return_rank  sharpe_rank  alpha_rank  expense_rank  dd_rank  \
# ...

# %% [markdown]
# # Historical VaR and CVaR Analysis

# %%
nav["date"] = pd.to_datetime(
    nav["date"]
)
nav = nav.sort_values(
    ["amfi_code","date"]
)
nav["daily_return"] = (
    nav.groupby("amfi_code")
       ["nav"]
       .pct_change()
)

# %%
nav[
    ["amfi_code",
     "date",
     "nav",
     "daily_return"]
].head()
# Out:
#    amfi_code       date       nav  daily_return
# 0     100016 2022-01-03  520.4608           NaN
# 1     100016 2022-01-04  515.0971     -0.010306
# 2     100016 2022-01-05  521.7239      0.012865
# 3     100016 2022-01-06  515.7880     -0.011377
# 4     100016 2022-01-07  515.1639     -0.001210

# %%
risk_report = []
for fund, data in nav.groupby("amfi_code"):

    returns = data[
        "daily_return"
    ].dropna()

    if len(returns) < 30:
        continue

    var95 = np.percentile(
        returns,
        5
    )

    cvar95 = returns[
        returns <= var95
    ].mean()

    risk_report.append([
        fund,
        var95,
        cvar95
    ])

# %%
var_cvar = pd.DataFrame(
    risk_report,
    columns=[
        "amfi_code",
        "VaR_95",
        "CVaR_95"
    ]
)

var_cvar.head()
# Out:
#    amfi_code    VaR_95   CVaR_95
# 0     100016 -0.014364 -0.018060
# 1     100025 -0.003793 -0.004994
# 2     100033 -0.019034 -0.023456
# 3     101206 -0.013282 -0.017439
# 4     101207 -0.026021 -0.032459

# %%
var_cvar.to_csv(
    "../Outputs/var_cvar_report.csv",
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 var_cvar.to_csv(
#       2     "../Outputs/var_cvar_report.csv",
#       3     index=False
#       4 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
var_cvar.to_csv(
    "../Data/Processed/var_cvar_report.csv",
    index=False
)

# %%
var_cvar.head()
# Out:
#    amfi_code    VaR_95   CVaR_95
# 0     100016 -0.014364 -0.018060
# 1     100025 -0.003793 -0.004994
# 2     100033 -0.019034 -0.023456
# 3     101206 -0.013282 -0.017439
# 4     101207 -0.026021 -0.032459

# %%
var_cvar.to_csv(
    "../Data/Processed/var_cvar_report.csv",
    index=False
)

# %%
scorecard.columns.tolist()
# Out:
# ['amfi_code',
#  'scheme_name',
#  'return_3yr_pct',
#  'expense_ratio_pct',
#  'sharpe_ratio',
#  'alpha',
#  'beta',
#  'max_drawdown',
#  'return_rank',
#  'sharpe_rank',
#  'alpha_rank',
#  'expense_rank',
#  'dd_rank',
#  'fund_score']

# %%
holdings.columns.tolist()
# Out:
# ['amfi_code',
#  'stock_symbol',
#  'stock_name',
#  'sector',
#  'weight_pct',
#  'market_value_cr',
#  'current_price_inr',
#  'portfolio_date']

# %% [markdown]
# # Rolling 90-Day Sharpe Ratio

# %%
nav["daily_return"] = (
    nav.groupby("amfi_code")["nav"]
       .pct_change()
)

# %%
top5_funds = (
    scorecard
    .sort_values(
        "fund_score",
        ascending=False
    )
    .head(5)
)

top5_funds[
    ["amfi_code","scheme_name"]
]
# Out:
#    amfi_code                                        scheme_name
# 0     119598         SBI Small Cap Fund - Regular Plan - Growth
# 1     120505           ICICI Pru Midcap Fund - Regular - Growth
# 2     149324              DSP Small Cap Fund - Regular - Growth
# 3     100033  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 4     120843             Kotak Flexicap Fund - Regular - Growth

# %%
plt.figure(figsize=(12,6))
for fund in top5_funds["amfi_code"]:

    temp = nav[
        nav["amfi_code"] == fund
    ].copy()

    rolling_sharpe = (
        temp["daily_return"]
        .rolling(90)
        .mean()
        /
        temp["daily_return"]
        .rolling(90)
        .std()
    ) * np.sqrt(252)

    plt.plot(
        temp["date"],
        rolling_sharpe,
        label=str(fund)
    )

plt.title(
    "Rolling 90-Day Sharpe Ratio"
)

plt.legend()

plt.tight_layout()

plt.show()

# %%
import os
os.makedirs(
    "../reports",
    exist_ok=True
)

# %%
plt.figure(figsize=(12,6))
for fund in top5_funds["amfi_code"]:

    temp = nav[
        nav["amfi_code"] == fund
    ].copy()

    rolling_sharpe = (
        temp["daily_return"]
        .rolling(90)
        .mean()
        /
        temp["daily_return"]
        .rolling(90)
        .std()
    ) * np.sqrt(252)

    plt.plot(
        temp["date"],
        rolling_sharpe,
        label=str(fund)
    )

plt.title(
    "Rolling 90-Day Sharpe Ratio"
)

plt.legend()

plt.savefig(
    "../reports/rolling_sharpe_chart.png"
)

plt.show()

# %%
transactions.columns.tolist()
# Out:
# ['investor_id',
#  'transaction_date',
#  'amfi_code',
#  'transaction_type',
#  'amount_inr',
#  'state',
#  'city',
#  'city_tier',
#  'age_group',
#  'gender',
#  'annual_income_lakh',
#  'payment_mode',
#  'kyc_status']

# %% [markdown]
# # Investor Cohort Analysis

# %%
transactions["transaction_date"] = pd.to_datetime(
    transactions["transaction_date"]
)

# %%
first_year = (
    transactions
    .groupby("investor_id")
    ["transaction_date"]
    .min()
    .dt.year
)
first_year.head()
# Out:
# investor_id
# INV000001    2024
# INV000002    2024
# INV000003    2024
# INV000004    2024
# INV000005    2024
# Name: transaction_date, dtype: int32

# %%
transactions = transactions.merge(
    first_year.rename("cohort_year"),
    on="investor_id"
)
transactions.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status  cohort_year
# 0          UPI   Verified         2024
# ...

# %%
cohort_summary = (
    transactions
    .groupby("cohort_year")
    .agg(
        avg_investment=(
            "amount_inr",
            "mean"
        ),
        total_invested=(
            "amount_inr",
            "sum"
        ),
        investors=(
            "investor_id",
            "nunique"
        )
    )
    .reset_index()
)

cohort_summary
# Out:
#    cohort_year  avg_investment  total_invested  investors
# 0         2024   107422.541832      3491125187       4803
# 1         2025   109158.577061        30455243        197

# %%
cohort_fund = (
    transactions
    .groupby(
        ["cohort_year","amfi_code"]
    )
    .size()
    .reset_index(name="transactions")
)

top_funds = (
    cohort_fund
    .sort_values(
        ["cohort_year","transactions"],
        ascending=False
    )
    .groupby("cohort_year")
    .head(1)
)

top_funds
# Out:
#     cohort_year  amfi_code  transactions
# 62         2025     119599            12
# 35         2024     148568           874

# %%
cohort_summary.to_csv(
    "../Data/Processed/cohort_analysis.csv",
    index=False
)

# %% [markdown]
# # SIP Continuity Analysis

# %%
sip = transactions[
    transactions["transaction_type"] == "SIP"
].copy()

sip.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 5   INV001497       2024-01-01     101208              SIP        3295
# 6   INV000786       2024-01-01     101208              SIP       15047
#
#             state       city city_tier age_group  gender  annual_income_lakh  \
# 0       Telangana  Hyderabad       T30       56+  Female                77.1
# 2         Haryana  Faridabad       B30     36-45    Male                47.2
# 3     Maharashtra     Mumbai       T30     36-45  Female                54.4
# 5     Maharashtra     Mumbai       T30     36-45    Male                56.8
# 6  Madhya Pradesh     Bhopal       B30     26-35    Male                17.9
#
#   payment_mode kyc_status  cohort_year
# ...

# %%
sip = sip.sort_values(
    ["investor_id","transaction_date"]
)

# %%
sip["gap_days"] = (
    sip.groupby("investor_id")
       ["transaction_date"]
       .diff()
       .dt.days
)

sip.head()
# Out:
#       investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 19621   INV000001       2024-11-04     120505              SIP       44856
# 24448   INV000001       2025-01-19     125497              SIP        3090
# 5650    INV000002       2024-03-29     149322              SIP        2830
# 16803   INV000002       2024-09-21     120841              SIP        2354
# 31881   INV000002       2025-05-17     119094              SIP        2690
#
#              state      city city_tier age_group gender  annual_income_lakh  \
# 19621      Haryana  Gurugram       T30     36-45   Male                19.9
# 24448      Haryana  Gurugram       T30     36-45   Male                19.9
# 5650   Maharashtra      Pune       T30     46-55   Male                24.0
# 16803  Maharashtra      Pune       T30     46-55   Male                24.0
# 31881  Maharashtra      Pune       T30     46-55   Male                24.0
#
#       payment_mode kyc_status  cohort_year  gap_days
# ...

# %%
continuity = (
    sip.groupby("investor_id")
    .agg(
        avg_gap_days=(
            "gap_days",
            "mean"
        ),
        sip_count=(
            "transaction_date",
            "count"
        )
    )
    .reset_index()
)

continuity.head()
# Out:
#   investor_id  avg_gap_days  sip_count
# 0   INV000001          76.0          2
# 1   INV000002         207.0          3
# 2   INV000003         238.0          2
# 3   INV000004          85.4          6
# 4   INV000005          14.0          3

# %%
continuity = continuity[
    continuity["sip_count"] >= 6
]

# %%
continuity["risk_flag"] = np.where(
    continuity["avg_gap_days"] > 35,
    "At Risk",
    "Healthy"
)

continuity.head()
# Out:
#    investor_id  avg_gap_days  sip_count risk_flag
# 3    INV000004     85.400000          6   At Risk
# 7    INV000008     70.400000          6   At Risk
# 9    INV000010     64.800000          6   At Risk
# 10   INV000011     40.166667          7   At Risk
# 11   INV000012     57.000000          8   At Risk

# %%
continuity["risk_flag"].value_counts()
# Out:
# risk_flag
# At Risk    1332
# Healthy      30
# Name: count, dtype: int64

# %%
continuity.to_csv(
    "../Data/Processed/sip_continuity_report.csv",
    index=False
)

# %%
cohort_summary.head()

continuity["risk_flag"].value_counts()
# Out:
# risk_flag
# At Risk    1332
# Healthy      30
# Name: count, dtype: int64

# %% [markdown]
# # Fund Recommendation Engine

# %%
def recommend_funds(risk_level):

    if risk_level == "Low":

        subset = scorecard[
            scorecard["beta"] < 0.8
        ]

    elif risk_level == "Moderate":

        subset = scorecard[
            (scorecard["beta"] >= 0.8)
            &
            (scorecard["beta"] <= 1.1)
        ]

    else:

        subset = scorecard[
            scorecard["beta"] > 1.1
        ]

    return (
        subset
        .sort_values(
            "sharpe_ratio",
            ascending=False
        )
        [
            [
                "scheme_name",
                "sharpe_ratio",
                "fund_score"
            ]
        ]
        .head(3)
    )

# %%
recommend_funds("Low")
# Out:
#                                      scheme_name  sharpe_ratio  fund_score
# 7  Mirae Asset Large Cap Fund - Regular - Growth      1.448291     68.7500
# 4         Kotak Flexicap Fund - Regular - Growth      1.306744     75.2500
# 9  Mirae Asset Tax Saver Fund - Regular - Growth      1.234930     62.6875

# %%
recommend_funds("Moderate")
# Out:
# Empty DataFrame
# Columns: [scheme_name, sharpe_ratio, fund_score]
# Index: []

# %%
recommend_funds("High")
# Out:
# Empty DataFrame
# Columns: [scheme_name, sharpe_ratio, fund_score]
# Index: []

# %% [markdown]
# # Sector Concentration Analysis (HHI)HFGJF

# %%
holdings["weight_sq"] = (
    holdings["weight_pct"] / 100
) ** 2

# %%
hhi = (
    holdings
    .groupby("amfi_code")
    ["weight_sq"]
    .sum()
    .reset_index()
)

hhi.columns = [
    "amfi_code",
    "HHI"
]

hhi.head()
# Out:
#    amfi_code       HHI
# 0     100016  0.139534
# 1     100033  0.147592
# 2     101206  0.129332
# 3     101207  0.200700
# 4     102885  0.174709

# %%
hhi.sort_values(
    "HHI",
    ascending=False
).head(10)
# Out:
#     amfi_code       HHI
# 11     119092  0.206448
# 3      101207  0.200700
# 18     119599  0.174751
# 4      102885  0.174709
# 7      118632  0.168298
# 29     148568  0.167930
# 21     120505  0.157570
# 22     120506  0.153794
# 27     125498  0.152414
# 23     120841  0.149680

# %%
hhi.to_csv(
    "../Data/Processed/hhi_report.csv",
    index=False
)

# %% [markdown]
# # Advanced Insights
#
# ## Insight 1
# Funds with the most negative VaR and CVaR values exhibited significantly higher downside risk during adverse market periods.
#
# ## Insight 2
# Top-performing funds maintained consistently positive rolling Sharpe Ratios, indicating superior risk-adjusted performance.
#
# ## Insight 3
# Recent investor cohorts contributed the highest cumulative investment amounts, reflecting growing retail participation in mutual funds.
#
# ## Insight 4
# SIP continuity analysis identified 1332 at-risk investors versus only 30 healthy investors, indicating potential retention challenges.
#
# ## Insight 5
# Funds with higher HHI values displayed concentrated portfolios and greater exposure to a smaller number of securities.

# %%
hhi.head()
# Out:
#    amfi_code       HHI
# 0     100016  0.139534
# 1     100033  0.147592
# 2     101206  0.129332
# 3     101207  0.200700
# 4     102885  0.174709

# %%
recommend_funds("Moderate")
# Out:
# Empty DataFrame
# Columns: [scheme_name, sharpe_ratio, fund_score]
# Index: []

# %%
scorecard["beta"].describe()
# Out:
# count    40.000000
# mean     -0.001958
# std       0.035194
# min      -0.066951
# 25%      -0.023937
# 50%      -0.000067
# 75%       0.017026
# max       0.103497
# Name: beta, dtype: float64

# %%
scorecard.sort_values(
    "beta"
)[
    ["scheme_name","beta"]
].head()
# Out:
#                                   scheme_name      beta
# 19     Axis Small Cap Fund - Regular - Growth -0.066951
# 5         Axis Midcap Fund - Regular - Growth -0.066265
# 14     ABSL Small Cap Fund - Regular - Growth -0.065289
# 32  HDFC Top 100 Fund - Regular Plan - Growth -0.058268
# 28        UTI Mid Cap Fund - Regular - Growth -0.042125

# %%
scorecard.sort_values(
    "beta",
    ascending=False
)[
    ["scheme_name","beta"]
].head()
# Out:
#                                           scheme_name      beta
# 12     Nippon India Small Cap Fund - Regular - Growth  0.103497
# 11          SBI Small Cap Fund - Direct Plan - Growth  0.062002
# 18           HDFC Top 100 Fund - Direct Plan - Growth  0.048820
# 16  ICICI Pru Value Discovery Fund - Regular - Growth  0.041896
# 31             Kotak Bluechip Fund - Regular - Growth  0.036356

# %%
def recommend_funds(risk_level):

    if risk_level == "Low":

        subset = scorecard[
            scorecard["max_drawdown"] > -0.15
        ]

    elif risk_level == "Moderate":

        subset = scorecard[
            scorecard["max_drawdown"] > -0.25
        ]

    else:

        subset = scorecard

    return (
        subset
        .sort_values(
            "sharpe_ratio",
            ascending=False
        )
        [
            [
                "scheme_name",
                "sharpe_ratio",
                "fund_score"
            ]
        ]
        .head(3)
    )
